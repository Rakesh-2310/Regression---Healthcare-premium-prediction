# %% [markdown]
# # **Data Preprocessing**

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

# %% [markdown]
# Data Loading

# %%
df = pd.read_excel('premiums_rest.xlsx')
df['Genetical_Risk'] = 0

# %%
df.shape
# Out:
# (29904, 14)

# %%
df.head(5)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        Medical History Insurance_Plan  Annual_Premium_Amount  Genetical_Risk
# 0             Diabetes         Bronze                   9053               0
# 1             Diabetes         Bronze                  16339               0
# 2  High blood pressure         Silver                  18164               0
# 3           No Disease           Gold                  20303               0
# 4             Diabetes         Bronze                  15610               0

# %%
df.describe()
# Out:
#                 Age  Number Of Dependants  Income_Lakhs  \
# count  29904.000000          29904.000000  29904.000000
# mean      43.396536              2.380116     23.362059
# std       13.411893              1.431140     24.737076
# min       26.000000             -3.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max      356.000000              5.000000    930.000000
#
#        Annual_Premium_Amount  Genetical_Risk
# count           29904.000000         29904.0
# mean            20893.036684             0.0
# std              6935.844219             0.0
# min              3625.000000             0.0
# 25%             15698.000000             0.0
# 50%             20489.000000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Number Of Dependants',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical History', 'Insurance_Plan',
#        'Annual_Premium_Amount', 'Genetical_Risk'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(" ","_").str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29904 entries, 0 to 29903
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    29904 non-null  int64
#  1   gender                 29904 non-null  object
#  2   region                 29904 non-null  object
#  3   marital_status         29904 non-null  object
#  4   number_of_dependants   29904 non-null  int64
#  5   bmi_category           29904 non-null  object
#  6   smoking_status         29895 non-null  object
#  7   employment_status      29903 non-null  object
#  8   income_level           29895 non-null  object
#  9   income_lakhs           29904 non-null  int64
#  10  medical_history        29904 non-null  object
#  11  insurance_plan         29904 non-null  object
#  12  annual_premium_amount  29904 non-null  int64
#  13  genetical_risk         29904 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
df.isna().mean()*100
# Out:
# age                      0.000000
# gender                   0.000000
# region                   0.000000
# marital_status           0.000000
# number_of_dependants     0.000000
# bmi_category             0.000000
# smoking_status           0.030096
# employment_status        0.003344
# income_level             0.030096
# income_lakhs             0.000000
# medical_history          0.000000
# insurance_plan           0.000000
# annual_premium_amount    0.000000
# genetical_risk           0.000000
# dtype: float64

# %%
df['income_level'].unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L', nan], dtype=object)

# %%
df[df['income_level'].isna()]
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 4262    33    Male  Southeast        Married                     2
# 9155    27  Female  Northeast      Unmarried                     2
# 9198    52    Male  Northeast        Married                     3
# 10391   40  Female  Northeast        Married                     4
# 13435   37  Female  Southeast      Unmarried                     0
# 18166   39  Female  Southeast      Unmarried                     2
# 26461   40    Male  Southwest      Unmarried                     0
# 26978   28  Female  Southwest        Married                     3
# 28490   54    Male  Southwest        Married                     4
#
#       bmi_category smoking_status employment_status income_level  \
# 4262        Normal        Regular     Self-Employed          NaN
# 9155   Underweight     No Smoking        Freelancer          NaN
# 9198   Underweight     No Smoking        Freelancer          NaN
# 10391      Obesity        Regular     Self-Employed          NaN
# 13435  Underweight        Regular          Salaried          NaN
# 18166      Obesity     No Smoking               NaN          NaN
# 26461  Underweight     Occasional          Salaried          NaN
# 26978       Normal     No Smoking          Salaried          NaN
# 28490       Normal     Occasional     Self-Employed          NaN
#
#        income_lakhs      medical_history insurance_plan  \
# 4262              7  High blood pressure         Silver
# 9155              5           No Disease         Silver
# 9198              8              Thyroid         Silver
# 10391             8  High blood pressure         Silver
# 13435             7  High blood pressure         Silver
# 18166             8  High blood pressure         Silver
# 26461             6  High blood pressure         Silver
# 26978             7           No Disease         Silver
# 28490             2             Diabetes         Silver
#
#        annual_premium_amount  genetical_risk
# 4262                   18335               0
# 9155                   14469               0
# 9198                   19535               0
# 10391                  22392               0
# 13435                  18631               0
# 18166                  20114               0
# 26461                  16663               0
# 26978                  13901               0
# 28490                  19531               0

# %%
df['employment_status'].unique()
# Out:
# array(['Salaried', 'Self-Employed', 'Freelancer', nan], dtype=object)

# %%
df['medical_history'].unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %%
df[df['smoking_status'].isna()]
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 115     26  Female  Southwest        Married                     3
# 9313    47    Male  Southwest        Married                     4
# 9728    45    Male  Northwest        Married                     4
# 10096   34    Male  Southwest        Married                     5
# 10736   61  Female  Southwest        Married                     2
# 12122   50  Female  Northeast        Married                     3
# 13604   69    Male  Southeast        Married                     2
# 15223   54    Male  Southwest        Married                     3
# 16286   58  Female  Southwest        Married                     3
#
#       bmi_category smoking_status employment_status income_level  \
# 115    Underweight            NaN          Salaried        > 40L
# 9313        Normal            NaN        Freelancer    25L - 40L
# 9728    Overweight            NaN          Salaried    10L - 25L
# 10096       Normal            NaN     Self-Employed    25L - 40L
# 10736       Normal            NaN     Self-Employed    25L - 40L
# 12122  Underweight            NaN          Salaried    25L - 40L
# 13604       Normal            NaN        Freelancer         <10L
# 15223   Overweight            NaN          Salaried        > 40L
# 16286      Obesity            NaN     Self-Employed    25L - 40L
#
#        income_lakhs                      medical_history insurance_plan  \
# 115              69                             Diabetes           Gold
# 9313             32                             Diabetes           Gold
# 9728             16  High blood pressure & Heart disease         Silver
# 10096            35  High blood pressure & Heart disease           Gold
# 10736            27                              Thyroid           Gold
# 12122            25                  High blood pressure           Gold
# 13604             9                             Diabetes         Silver
# 15223            54  High blood pressure & Heart disease         Silver
# 16286            32                             Diabetes           Gold
#
#        annual_premium_amount  genetical_risk
# 115                    22605               0
# 9313                   26100               0
# 9728                   21881               0
# 10096                  25865               0
# 10736                  32501               0
# 12122                  27317               0
# 13604                  23118               0
# 15223                  24907               0
# 16286                  30112               0

# %%
df[(df['medical_history'] == 'High blood pressure & Heart disease') & (df['bmi_category'] == 'Overweight')]['smoking_status'].mode()
# Out:
# 0    Regular
# Name: smoking_status, dtype: object

# %%
smoking_mode = (
    df.groupby(['medical_history', 'bmi_category'])['smoking_status']
    .agg(lambda x: pd.Series.mode(x)[0] if not pd.Series.mode(x).empty else None)
    .reset_index()
)

print(smoking_mode)
# Out:
#                         medical_history bmi_category smoking_status
# 0                              Diabetes       Normal     No Smoking
# 1                              Diabetes      Obesity     No Smoking
# 2                              Diabetes   Overweight        Regular
# 3                              Diabetes  Underweight     No Smoking
# 4              Diabetes & Heart disease       Normal     No Smoking
# 5              Diabetes & Heart disease      Obesity     No Smoking
# 6              Diabetes & Heart disease   Overweight        Regular
# 7              Diabetes & Heart disease  Underweight     No Smoking
# 8        Diabetes & High blood pressure       Normal     No Smoking
# 9        Diabetes & High blood pressure      Obesity     No Smoking
# 10       Diabetes & High blood pressure   Overweight        Regular
# 11       Diabetes & High blood pressure  Underweight     No Smoking
# 12                   Diabetes & Thyroid       Normal     No Smoking
# 13                   Diabetes & Thyroid      Obesity        Regular
# 14                   Diabetes & Thyroid   Overweight     No Smoking
# 15                   Diabetes & Thyroid  Underweight        Regular
# 16                        Heart disease       Normal     No Smoking
# 17                        Heart disease      Obesity     No Smoking
# 18                        Heart disease   Overweight        Regular
# 19                        Heart disease  Underweight     No Smoking
# 20                  High blood pressure       Normal     No Smoking
# 21                  High blood pressure      Obesity     No Smoking
# 22                  High blood pressure   Overweight        Regular
# 23                  High blood pressure  Underweight     No Smoking
# 24  High blood pressure & Heart disease       Normal     No Smoking
# 25  High blood pressure & Heart disease      Obesity     No Smoking
# 26  High blood pressure & Heart disease   Overweight        Regular
# 27  High blood pressure & Heart disease  Underweight     No Smoking
# 28                           No Disease       Normal     No Smoking
# 29                           No Disease      Obesity     No Smoking
# 30                           No Disease   Overweight     No Smoking
# 31                           No Disease  Underweight     No Smoking
# 32                              Thyroid       Normal     No Smoking
# 33                              Thyroid      Obesity     No Smoking
# 34                              Thyroid   Overweight        Regular
# 35                              Thyroid  Underweight     No Smoking

# %%
"""
Handling Missing Values:

- income_level:
  Missingness is likely dependent on the observed feature income_lakhs,
  as both represent income information. Hence, this is classified as MAR
  (Missing At Random). I impute income_level using income_lakhs.

- smoking_status:
  Missingness is likely related to the unobserved value itself, as individuals
  may choose not to disclose their smoking habits. Therefore, it is classified
  as MNAR (Missing Not At Random). Instead of naive imputation, I treat missing
  values as a separate category ('Unknown') and optionally create a missing indicator.

- employment_status:
  Missingness does not appear to depend on the value itself but may depend on
  other observed features such as income_level. Hence, it is treated as MAR.
  I impute missing values using conditional mode imputation based on income_level.
"""
# Out:
# "\nHandling Missing Values:\n\n- income_level:\n  Missingness is likely dependent on the observed feature income_lakhs,\n  as both represent income information. Hence, this is classified as MAR\n  (Missing At Random). I impute income_level using income_lakhs.\n\n- smoking_status:\n  Missingness is likely related to the unobserved value itself, as individuals\n  may choose not to disclose their smoking habits. Therefore, it is classified\n  as MNAR (Missing Not At Random). Instead of naive imputation, I treat missing\n  values as a separate category ('Unknown') and optionally create a missing indicator.\n\n- employment_status:\n  Missingness does not appear to depend on the value itself but may depend on\n  other observed features such as income_level. Hence, it is treated as MAR.\n  I impute missing values using conditional mode imputation based on income_level.\n"

# %%
def map_income_level(x):
    if pd.isna(x):
        return None
    elif x < 10:
        return '<10L'
    elif 10 <= x < 25:
        return '10L - 25L'
    elif 25 <= x < 40:
        return '25L - 40L'
    else:
        return '> 40L'

# %%
mask = df['income_level'].isna()
df.loc[mask, 'income_level'] = df.loc[mask, 'income_lakhs'].apply(map_income_level)

# %%
df['smoking_status'] = df['smoking_status'].fillna('Unknown')

# %%
global_mode = df['employment_status'].mode()[0]

def fill_mode_safe(series):
    mode = series.mode()
    return series.fillna(mode[0] if not mode.empty else global_mode)

df['employment_status'] = (
    df.groupby('income_level')['employment_status']
      .transform(fill_mode_safe)
)

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29904.000000          29904.000000  29904.000000
# mean      43.396536              2.380116     23.362059
# std       13.411893              1.431140     24.737076
# min       26.000000             -3.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max      356.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29904.000000         29904.0
# mean            20893.036684             0.0
# std              6935.844219             0.0
# min              3625.000000             0.0
# 25%             15698.000000             0.0
# 50%             20489.000000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
df['number_of_dependants'].value_counts()/len(df)*100
# Out:
# number_of_dependants
#  3    31.761637
#  2    20.706260
#  4    15.807250
#  0    15.295613
#  1    10.731006
#  5     5.531033
# -1     0.100321
# -3     0.066881
# Name: count, dtype: float64

# %%
df['number_of_dependants'] = df['number_of_dependants'].abs()

# %%
import matplotlib.pyplot as plt

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

for col in numeric_columns:
  df.boxplot(column=col, grid=False, figsize=(8, 6))
  plt.show()

# %%
def remove_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return df[(df[col] >= lower) & (df[col] <= upper)]

df = remove_outliers_iqr(df, 'age')

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29846.000000          29846.000000  29846.000000
# mean      43.095993              2.387992     23.369396
# std       11.042658              1.420585     24.747987
# min       26.000000              0.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max       72.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29846.000000         29846.0
# mean            20902.629063             0.0
# std              6927.489391             0.0
# min              6538.000000             0.0
# 25%             15707.000000             0.0
# 50%             20496.500000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
  print(f"{col}:{df[col].unique()}")
# Out:
# gender:['Male' 'Female']
# region:['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status:['Unmarried' 'Married']
# bmi_category:['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status:['No Smoking' 'Regular' 'Occasional' 'Unknown' 'Does Not Smoke'
#  'Not Smoking' 'Smoking=0']
# employment_status:['Salaried' 'Self-Employed' 'Freelancer']
# income_level:['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history:['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan:['Bronze' 'Silver' 'Gold']

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['smoking_status'] = df['smoking_status'].replace({
    'Not Smoking': 'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Smoking=0': 'No Smoking'
})

df['smoking_status'].unique()
# Out:
# array(['No Smoking', 'Regular', 'Occasional', 'Unknown'], dtype=object)

# %%
import seaborn as sns

fig, axes = plt.subplots(3, 3, figsize=(18, 18))  # Adjust figure size as necessary
axes = axes.flatten()  # Flatten the 2D array of axes into 1D for easier iteration

for ax, column in zip(axes, categorical_cols):
    # Calculate the percentage distribution of each category
    category_counts = df[column].value_counts(normalize=True) * 100  # normalize=True gives the relative frequencies

    # Plotting the distribution using barplot
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax)
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(column)  # Set xlabel to the column name for clarity

plt.tight_layout()  # Adjusts plot parameters for better fit in the figure window
plt.show()

# %%
crosstab = pd.crosstab(df['income_level'], df['insurance_plan'])
print(crosstab)
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          799  3554    4355
# 25L - 40L          301  2636    3142
# <10L              6054   527    4351
# > 40L              214  3293     620

# %%
sns.heatmap(crosstab, annot=True, cmap='coolwarm',fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %%
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

df[['disease1', 'disease2']] = df['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df['disease1'] = df['disease1'].fillna('none')
df['disease2'] = df['disease2'].fillna('none')
df['total_risk_score'] = 0

for disease in ['disease1', 'disease2']:
    df['total_risk_score'] += df[disease].map(risk_scores)

# Normalize the risk score to a range of 0 to 1
max_score = df['total_risk_score'].max()
min_score = df['total_risk_score'].min()
df['normalized_risk_score'] = (df['total_risk_score'] - min_score) / (max_score - min_score)
df.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount  genetical_risk  disease1 disease2  \
# 0         Bronze                   9053               0  diabetes     none
# 1         Bronze                  16339               0  diabetes     none
#
#    total_risk_score  normalized_risk_score
# 0                 6               0.428571
# 1                 6               0.428571

# %%
df['insurance_plan'] = df['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df['income_level'] = df['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df = pd.get_dummies(df, columns=nominal_cols, drop_first=True, dtype=int)
df.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
#
#    insurance_plan  annual_premium_amount  genetical_risk             disease1  \
# 0               1                   9053               0             diabetes
# 1               1                  16339               0             diabetes
# 2               2                  18164               0  high blood pressure
#
#   disease2  ...  region_Southwest  marital_status_Unmarried  \
# 0     none  ...                 0                         1
# 1     none  ...                 0                         0
# 2     none  ...                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  smoking_status_Unknown  \
# 0                          0                       0                       0
# 1                          0                       1                       0
# 2                          0                       0                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
#
# [3 rows x 25 columns]

# %%
df = df.drop(['medical_history','disease1', 'disease2', 'total_risk_score'], axis=1)
df.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
# 2   49                     2             2            20               2
#
#    annual_premium_amount  genetical_risk  normalized_risk_score  gender_Male  \
# 0                   9053               0               0.428571            1
# 1                  16339               0               0.428571            0
# 2                  18164               0               0.428571            0
#
#    region_Northwest  ...  region_Southwest  marital_status_Unmarried  \
# 0                 1  ...                 0                         1
# 1                 0  ...                 0                         0
# 2                 0  ...                 0                         0
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 0                     0                        0                         0
# 1                     1                        0                         0
# 2                     0                        0                         0
#
#    smoking_status_Occasional  smoking_status_Regular  smoking_status_Unknown  \
# 0                          0                       0                       0
# 1                          0                       1                       0
# 2                          0                       0                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 0                           1                                0
# 1                           1                                0
# 2                           0                                1
#
# [3 rows x 21 columns]

# %%
cm = df.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X = df.drop('annual_premium_amount', axis='columns')
y = df['annual_premium_amount']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan', 'genetical_risk']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  29846.000000          29846.000000  29846.000000  29846.000000
# mean       0.371652              0.477598      0.371317      0.024079
# std        0.240058              0.284117      0.351207      0.026639
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.173913              0.200000      0.000000      0.006459
# 50%        0.347826              0.600000      0.333333      0.017223
# 75%        0.565217              0.600000      0.666667      0.033369
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  genetical_risk  normalized_risk_score   gender_Male  \
# count    29846.000000         29846.0           29846.000000  29846.000000
# mean         0.544261             0.0               0.426394      0.549119
# std          0.378959             0.0               0.240104      0.497590
# min          0.000000             0.0               0.000000      0.000000
# 25%          0.500000             0.0               0.357143      0.000000
# 50%          0.500000             0.0               0.428571      1.000000
# 75%          1.000000             0.0               0.428571      1.000000
# max          1.000000             0.0               1.000000      1.000000
#
#        region_Northwest  region_Southeast  region_Southwest  \
# count      29846.000000      29846.000000      29846.000000
# mean           0.200630          0.352610          0.302051
# std            0.400478          0.477791          0.459155
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000          1.000000          1.000000
# max            1.000000          1.000000          1.000000
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# count              29846.000000          29846.000000
# mean                   0.253300              0.196911
# std                    0.434909              0.397671
# min                    0.000000              0.000000
# 25%                    0.000000              0.000000
# 50%                    0.000000              0.000000
# 75%                    1.000000              0.000000
# max                    1.000000              1.000000
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# count             29846.000000              29846.000000
# mean                  0.294914                  0.110199
# std                   0.456012                  0.313143
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   1.000000                  0.000000
# max                   1.000000                  1.000000
#
#        smoking_status_Occasional  smoking_status_Regular  \
# count               29846.000000            29846.000000
# mean                    0.173189                0.374489
# std                     0.378417                0.483999
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                1.000000
# max                     1.000000                1.000000
#
#        smoking_status_Unknown  employment_status_Salaried  \
# count            29846.000000                29846.000000
# mean                 0.000302                    0.466126
# std                  0.017363                    0.498860
# min                  0.000000                    0.000000
# 25%                  0.000000                    0.000000
# 50%                  0.000000                    0.000000
# 75%                  0.000000                    1.000000
# max                  1.000000                    1.000000
#
#        employment_status_Self-Employed
# count                     29846.000000
# mean                          0.354252
# std                           0.478294
# min                           0.000000
# 25%                           0.000000
# 50%                           0.000000
# 75%                           1.000000
# max                           1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
# c:\Users\rakes\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                              Column       VIF
# 0                               age  3.919228
# 1              number_of_dependants  6.275631
# 2                      income_level  8.502793
# 3                      income_lakhs  5.948744
# 4                    insurance_plan  5.256121
# 5                    genetical_risk       NaN
# 6             normalized_risk_score  3.811930
# 7                       gender_Male  2.597394
# 8                  region_Northwest  2.123282
# 9                  region_Southeast  2.979215
# 10                 region_Southwest  2.709887
# 11         marital_status_Unmarried  2.344635
# 12             bmi_category_Obesity  1.478897
# 13          bmi_category_Overweight  1.734724
# 14         bmi_category_Underweight  1.255750
# 15        smoking_status_Occasional  1.378185
# 16           smoking_status_Regular  2.131092
# 17           smoking_status_Unknown  1.001490
# 18       employment_status_Salaried  3.174482
# 19  employment_status_Self-Employed  2.871644

# %%
calculate_vif(X.drop('income_level', axis="columns"))
# Out:
# c:\Users\rakes\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.uncentered_tss
#                              Column       VIF
# 0                               age  3.847054
# 1              number_of_dependants  6.271351
# 2                      income_lakhs  2.326801
# 3                    insurance_plan  4.333418
# 4                    genetical_risk       NaN
# 5             normalized_risk_score  3.808895
# 6                       gender_Male  2.590568
# 7                  region_Northwest  2.122013
# 8                  region_Southeast  2.977134
# 9                  region_Southwest  2.706516
# 10         marital_status_Unmarried  2.342309
# 11             bmi_category_Obesity  1.478149
# 12          bmi_category_Overweight  1.734398
# 13         bmi_category_Underweight  1.255300
# 14        smoking_status_Occasional  1.378012
# 15           smoking_status_Regular  2.130487
# 16           smoking_status_Unknown  1.001395
# 17       employment_status_Salaried  3.169238
# 18  employment_status_Self-Employed  2.863932

# %%
# # we will drop income_lakhs due to high VIF value
# X_reduced = X.drop('income_level', axis="columns")

# %% [markdown]
# <h2 align="center" style="color:blue">Model Training</h2>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (20892, 20)
# x test:  (8954, 20)
# y train:  (20892,)
# y test:  (8954,)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
test_score = model_lr.score(X_test, y_test)
train_score = model_lr.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9537545598790524, 0.9532277772769381)

# %%
y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  2223729.6356374403 RMSE:  1491.2175011169363

# %%
X_test.shape
# Out:
# (8954, 20)

# %%
np.set_printoptions(suppress=True, precision=6)
model_lr.coef_
# Out:
# array([ 6976.963969, -1285.914043,  -494.14698 , -1222.477088,
#        14930.091014,     0.      ,  6002.50273 ,    61.143184,
#          -36.058854,    -9.614945,   -19.545737,  -691.209206,
#         3916.326266,  1970.863222,   590.641676,   828.846293,
#         2792.469397,   775.046588,   -79.68608 ,   229.302724])

# %%
feature_importance = model_lr.coef_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %%
# Ridge Regression Model
model_rg = Ridge(alpha=1)
model_rg.fit(X_train, y_train)
test_score = model_rg.score(X_test, y_test)
train_score = model_rg.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9537541522013236, 0.9532266260278071)

# %%
y_pred = model_rg.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Ridge Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Ridge Regression ==> MSE:  2223784.3704065355 RMSE:  1491.2358533801873

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(n_estimators=20, max_depth=3)
model_xgb.fit(X_train, y_train)
model_xgb.score(X_test, y_test)
# Out:
# 0.9935792307303402

# %%
y_pred = model_xgb.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("XGBoost Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# XGBoost Regression ==> MSE:  305267.82943528215 RMSE:  552.5104790275766

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=None)
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# 0.9969866446741356

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in XGBoost')
plt.show()

# %%
y_pred = best_model.predict(X_test)

residuals = y_pred - y_test
residuals_pct = (residuals / y_test) * 100

results_df = pd.DataFrame({
    'actual': y_test,
    'predicted': y_pred,
    'diff': residuals,
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#        actual     predicted        diff  diff_pct
# 24685   31624  31375.072266 -248.927734 -0.787148
# 7548    22385  22558.871094  173.871094  0.776730
# 14698   18208  18936.068359  728.068359  3.998618
# 25288   11190  11229.176758   39.176758  0.350105
# 22874   15533  15898.896484  365.896484  2.355607

# %%
sns.histplot(results_df['diff_pct'], kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
extreme_error_threshold = 10  # You can adjust this threshold based on your domain knowledge or requirements
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.head()
# Out:
#        actual    predicted         diff   diff_pct
# 11189    8563  9447.992188   884.992188  10.335072
# 1549     8543  9447.992188   904.992188  10.593377
# 12189    6571  7605.027344  1034.027344  15.736225
# 28595    7580  8427.613281   847.613281  11.182233
# 12499    6801  7605.027344   804.027344  11.822193

# %%
extreme_results_df.shape
# Out:
# (35, 4)

# %%
extreme_errors_pct = extreme_results_df.shape[0]*100/X_test.shape[0]
extreme_errors_pct
# Out:
# 0.39088675452311816

# %%
from joblib import dump

dump(best_model, "model_rest.joblib")
scaler_with_cols = {
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(scaler_with_cols, "scaler_rest.joblib")
# Out:
# ['scaler_rest.joblib']
